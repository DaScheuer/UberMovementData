# %%
import glob
import os
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt

# %%
# Specify correct location where datasets are stored
path = r'C:\Users\I539797\Documents\GitHub\UberMovementDataDownloadBot\Datasets\Boston'

# %%
# Merge/Concatenate all datasets into one
df = pd.concat(map(pd.read_csv, glob.glob(os.path.join(r'C:\Users\I539797\Documents\GitHub\UberMovementDataDownloadBot\Datasets\Boston', "*.csv"))))

# %%
df.head(10)
# Out:
#   Origin Movement ID             Origin Display Name Destination Movement ID  \
# 0               1116  Harborwalk, Waterfront, Boston                       3
# 1               1116  Harborwalk, Waterfront, Boston                       5
# 2               1116  Harborwalk, Waterfront, Boston                      13
# 3               1116  Harborwalk, Waterfront, Boston                      14
# 4               1116  Harborwalk, Waterfront, Boston                      16
# 5               1116  Harborwalk, Waterfront, Boston                      17
# 6               1116  Harborwalk, Waterfront, Boston                      18
# 7               1116  Harborwalk, Waterfront, Boston                      20
# 8               1116  Harborwalk, Waterfront, Boston                      21
# 9               1116  Harborwalk, Waterfront, Boston                      27
#
#                            Destination Display Name  \
# 0  0 Flaherty Way, D Street / West Broadway, Boston
# 1      0 Queensberry Street, Fenway/Kenmore, Boston
# 2                     200 Liberty Street, Braintree
# 3                       400 Cushing Street, Hingham
# 4            100 Kenrick Street, Oak Square, Boston
# 5                              0 Maggi Road, Revere
# 6                          0 Lake Street, Billerica
# 7                        0 Florence Street, Everett
# 8                          0 Canal Lane, Somerville
# 9       100 Inner Belt Road, Inner Belt, Somerville
#
#                                       Date Range Mean Travel Time (Seconds)  \
# 0  2/3/2016 - 2/3/2016, Every day, Daily Average                        596
# 1  2/3/2016 - 2/3/2016, Every day, Daily Average                        697
# 2  2/3/2016 - 2/3/2016, Every day, Daily Average                       1152
# 3  2/3/2016 - 2/3/2016, Every day, Daily Average                       1608
# 4  2/3/2016 - 2/3/2016, Every day, Daily Average                       1395
# 5  2/3/2016 - 2/3/2016, Every day, Daily Average                        745
# 6  2/3/2016 - 2/3/2016, Every day, Daily Average                       1776
# 7  2/3/2016 - 2/3/2016, Every day, Daily Average                        944
# 8  2/3/2016 - 2/3/2016, Every day, Daily Average                        457
# 9  2/3/2016 - 2/3/2016, Every day, Daily Average                        345
#
#   Range - Lower Bound Travel Time (Seconds)  \
# 0                                       395
# 1                                       467
# 2                                       865
# 3                                      1200
# 4                                      1075
# 5                                       485
# 6                                      1386
# 7                                       749
# 8                                       260
# 9                                       162
#
#   Range - Upper Bound Travel Time (Seconds)
# 0                                       897
# 1                                      1039
# 2                                      1532
# 3                                      2152
# 4                                      1809
# 5                                      1143
# 6                                      2275
# 7                                      1189
# 8                                       800
# 9                                       733

# %%
# Create a numeric index, because the existing index will be replaced by the Date Range later
df['Numeric Index'] = range(len(df))

# Reorder columns
df = df[['Numeric Index',
         'Origin Movement ID',
         'Origin Display Name',
         'Destination Movement ID',
         'Destination Display Name',
         'Date Range',
         'Mean Travel Time (Seconds)',
         'Range - Lower Bound Travel Time (Seconds)',
         'Range - Upper Bound Travel Time (Seconds)',
        ]]

# %%
# Reformat date and sort values by date
df['Date Range'] = pd.to_datetime(df['Date Range'].str.split().str[0], format='%m/%d/%Y')
df = df.sort_values('Date Range')

df.head()
# Out:
#      Numeric Index Origin Movement ID             Origin Display Name  \
# 382         831362               1116  Harborwalk, Waterfront, Boston
# 119         831099               1116  Harborwalk, Waterfront, Boston
# 120         831100               1116  Harborwalk, Waterfront, Boston
# 121         831101               1116  Harborwalk, Waterfront, Boston
# 122         831102               1116  Harborwalk, Waterfront, Boston
#
#     Destination Movement ID       Destination Display Name Date Range  \
# 382                    1246       North Shore Road, Revere 2016-01-02
# 119                     366    0 Eastern Avenue, Arlington 2016-01-02
# 120                     367   0 Pleasant Street, Lexington 2016-01-02
# 121                     368     0 Hayden Avenue, Lexington 2016-01-02
# 122                     369  200 Waltham Street, Lexington 2016-01-02
#
#     Mean Travel Time (Seconds) Range - Lower Bound Travel Time (Seconds)  \
# 382                        919                                       732
# 119                        990                                       803
# 120                       1219                                       873
# 121                       1635                                      1093
# 122                       1647                                      1186
#
#     Range - Upper Bound Travel Time (Seconds)
# 382                                      1152
# 119                                      1220
# 120                                      1702
# 121                                      2444
# 122                                      2286

# %%
# Renaming 'Date Range' column to 'Date'
df = df.rename(columns={"Date Range": "Date"})

# Deleting columns that are not helpful for the analysis
df.drop('Origin Display Name', axis=1, inplace=True)
df.drop('Destination Display Name', axis=1, inplace=True)

# %%
df.head()
# Out:
#      Numeric Index Origin Movement ID Destination Movement ID       Date  \
# 382         831362               1116                    1246 2016-01-02
# 119         831099               1116                     366 2016-01-02
# 120         831100               1116                     367 2016-01-02
# 121         831101               1116                     368 2016-01-02
# 122         831102               1116                     369 2016-01-02
#
#     Mean Travel Time (Seconds) Range - Lower Bound Travel Time (Seconds)  \
# 382                        919                                       732
# 119                        990                                       803
# 120                       1219                                       873
# 121                       1635                                      1093
# 122                       1647                                      1186
#
#     Range - Upper Bound Travel Time (Seconds)
# 382                                      1152
# 119                                      1220
# 120                                      1702
# 121                                      2444
# 122                                      2286

# %%
df.set_index(df['Date'])
# Out:
#             Numeric Index Origin Movement ID Destination Movement ID  \
# Date
# 2016-01-02        1593391               1074                    1431
# 2016-01-02        1593015               1074                     761
# 2016-01-02        1593016               1074                     766
# 2016-01-02        1593017               1074                     767
# 2016-01-02        1593018               1074                     768
# ...                   ...                ...                     ...
# 2020-03-31        1592751               1074                    1178
# 2020-03-31        1592752               1074                    1179
# 2020-03-31        1592753               1074                    1180
# 2020-03-31        1592741               1074                    1162
# 2020-03-31        1592422               1074                     411
#
#                  Date MeanTravelTimeSeconds  \
# Date
# 2016-01-02 2016-01-02                  1400
# 2016-01-02 2016-01-02                  1095
# 2016-01-02 2016-01-02                  1647
# 2016-01-02 2016-01-02                  1298
# 2016-01-02 2016-01-02                  1033
# ...               ...                   ...
# 2020-03-31 2020-03-31                   780
# 2020-03-31 2020-03-31                   878
# 2020-03-31 2020-03-31                   568
# 2020-03-31 2020-03-31                   352
# 2020-03-31 2020-03-31                  1546
#
#            Range - Lower Bound Travel Time (Seconds)  \
# Date
# 2016-01-02                                      1055
# 2016-01-02                                       845
# 2016-01-02                                      1223
# 2016-01-02                                      1124
# 2016-01-02                                       744
# ...                                              ...
# 2020-03-31                                       680
# 2020-03-31                                       767
# 2020-03-31                                       445
# 2020-03-31                                       214
# 2020-03-31                                      1352
#
#            Range - Upper Bound Travel Time (Seconds) DayofWeek
# Date
# 2016-01-02                                      1856  Saturday
# 2016-01-02                                      1417  Saturday
# 2016-01-02                                      2217  Saturday
# 2016-01-02                                      1498  Saturday
# 2016-01-02                                      1432  Saturday
# ...                                              ...       ...
# 2020-03-31                                       893   Tuesday
# 2020-03-31                                      1003   Tuesday
# 2020-03-31                                       724   Tuesday
# 2020-03-31                                       576   Tuesday
# 2020-03-31                                      1766   Tuesday
#
# [1593392 rows x 8 columns]

# %%
# Count number of trips recorded on each day
df['Date'].value_counts()
# Out:
# 2019-06-08    687
# 2019-09-08    676
# 2019-10-12    675
# 2020-02-29    674
# 2019-12-13    673
#              ...
# 2020-03-26    288
# 2020-03-29    280
# 2020-03-30    275
# 2020-03-25    270
# 2020-03-31    262
# Name: Date, Length: 1516, dtype: int64

# %%
# Make sure that both of our axes have the same amount of datapoints
print(len(df['Date'].unique()))
print(len(df['Date'].value_counts()))

# Plot the distribution of amount of recorded daily trips (not based on time, but from day with highest amount
#     of recorded trips to day with least amount of recorded trips)
plt.figure(figsize=(50, 20))
plt.scatter(df['Date'].unique(), df['Date'].value_counts())
plt.xticks(fontsize=30, rotation=45)
plt.yticks(fontsize=30)
plt.xlabel("", fontsize=40)
plt.ylabel("Daily Number of Recorded Trips", fontsize=40)
# Out:
# 1516
# 1516
# Text(0, 0.5, 'Daily Number of Recorded Trips')

# %%
# Plotting the amount of recorded daily trips throught time
daily_trip_count = df.groupby('Date')['MeanTravelTimeSeconds'].count()

plt.figure(figsize=(50,20))
plt.scatter(df['Date'].unique(), daily_trip_count)

# We change the fontsize of minor ticks label 
plt.xticks(fontsize=30, rotation=45)
plt.yticks(fontsize=30)
plt.xlabel("Date", fontsize=40)
plt.ylabel("Daily Number of Recorded Trips", fontsize=40)
# Out:
# Text(0, 0.5, 'Daily Number of Recorded Trips')

# %%
# Removing sapces and odd character from column names
df = df.rename(columns={"Mean Travel Time (Seconds)": "MeanTravelTimeSeconds"})
df = df.rename(columns={"Numeric Index": "NumericIndex"})
df = df.rename(columns={"Origin Movement ID": "OriginMovementID"})
df = df.rename(columns={"Destination Movement ID": "DestinationMovementID"})
df = df.rename(columns={"Range - Lower Bound Travel Time (Seconds)": "RangeLowerBoundTravelTimeSeconds"})
df = df.rename(columns={"Range - Upper Bound Travel Time (Seconds)": "RangeUpperBoundTravelTimeSeconds"})

# %%
# df with renamed columns
df.head()
# Out:
#      NumericIndex OriginMovementID DestinationMovementID       Date  \
# 382        831362             1116                  1246 2016-01-02
# 119        831099             1116                   366 2016-01-02
# 120        831100             1116                   367 2016-01-02
# 121        831101             1116                   368 2016-01-02
# 122        831102             1116                   369 2016-01-02
#
#     MeanTravelTimeSeconds RangeLowerBoundTravelTimeSeconds  \
# 382                   919                              732
# 119                   990                              803
# 120                  1219                              873
# 121                  1635                             1093
# 122                  1647                             1186
#
#     RangeUpperBoundTravelTimeSeconds
# 382                             1152
# 119                             1220
# 120                             1702
# 121                             2444
# 122                             2286

# %%
# Create a 'DayofWeek' column
df['DayOfWeek'] = df['Date'].dt.day_name()
df.head()
# Out:
#      NumericIndex OriginMovementID DestinationMovementID       Date  \
# 382        831362             1116                  1246 2016-01-02
# 119        831099             1116                   366 2016-01-02
# 120        831100             1116                   367 2016-01-02
# 121        831101             1116                   368 2016-01-02
# 122        831102             1116                   369 2016-01-02
#
#     MeanTravelTimeSeconds RangeLowerBoundTravelTimeSeconds  \
# 382                   919                              732
# 119                   990                              803
# 120                  1219                              873
# 121                  1635                             1093
# 122                  1647                             1186
#
#     RangeUpperBoundTravelTimeSeconds DayOfWeek
# 382                             1152  Saturday
# 119                             1220  Saturday
# 120                             1702  Saturday
# 121                             2444  Saturday
# 122                             2286  Saturday

# %%
trip_count_DOW = df.groupby('DayOfWeek')['MeanTravelTimeSeconds'].count()
print(trip_count_DOW)

plt.bar(df['DayOfWeek'].unique(), trip_count_DOW)
# Out:
# DayOfWeek
# Friday       121182
# Monday       112790
# Saturday     125076
# Sunday       122579
# Thursday     119795
# Tuesday      113598
# Wednesday    116343
# Name: MeanTravelTimeSeconds, dtype: int64
# <BarContainer object of 7 artists>

# %%
df.loc[df['Date'] == '2016-01-03'].count()
# Out:
# NumericIndex                        0
# OriginMovementID                    0
# DestinationMovementID               0
# Date                                0
# MeanTravelTimeSeconds               0
# RangeLowerBoundTravelTimeSeconds    0
# RangeUpperBoundTravelTimeSeconds    0
# DayOfWeek                           0
# dtype: int64
