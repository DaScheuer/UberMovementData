# %%
import matplotlib.pyplot as plt
import numpy as np
from arch import arch_model
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import pandas as pd
from datetime import datetime

# %%
def parser(s):
    return datetime.strptime(s, '%Y-%m-%d')

# %%
#read data
df = pd.read_csv(r'C:\Users\I539797\Documents\Thesis\Datasets\Formatted Datasets\formatted_saopaulo.csv', parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
df.head()
# Out:
#             NumericIndex  OriginMovementID  DestinationMovementID  \
# Date
# 2016-01-02        502791                 5                    318
# 2016-01-02        502761                 5                     77
# 2016-01-02        502760                 5                     64
# 2016-01-02        502759                 5                     63
# 2016-01-02        502758                 5                     62
#
#             MeanTravelTimeSeconds  RangeLowerBoundTravelTimeSeconds  \
# Date
# 2016-01-02                    964                               814
# 2016-01-02                    563                               398
# 2016-01-02                    741                               583
# 2016-01-02                    661                               468
# 2016-01-02                    595                               393
#
#             RangeUpperBoundTravelTimeSeconds DayOfWeek
# Date
# 2016-01-02                              1141  Saturday
# 2016-01-02                               794  Saturday
# 2016-01-02                               940  Saturday
# 2016-01-02                               932  Saturday
# 2016-01-02                               899  Saturday

# %%
df = pd.DataFrame(df.groupby('Date')['MeanTravelTimeSeconds'].mean())
df.head()
# Out:
#             MeanTravelTimeSeconds
# Date
# 2016-01-02             744.509434
# 2016-01-03             899.809524
# 2016-01-04             905.813559
# 2016-01-05             909.786885
# 2016-01-06             929.409449

# %%
plt.figure(figsize=(10,4))
plt.plot(df)
plt.title('Time Series Data', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Simulated GARCH(2,2) Data')

# %%
df['pct_change'] = df['MeanTravelTimeSeconds'].pct_change().dropna()

# %%
plt.figure(figsize=(10,4))
plt.plot(df['pct_change'])
plt.title('Data Volatility', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Data Volatility')

# %%
plot_pacf(np.array(df['MeanTravelTimeSeconds'].diff().dropna())**2)
plt.show()

# %%
test_size = len(df['MeanTravelTimeSeconds']*0.1)
train, test = df['MeanTravelTimeSeconds'][:-test_size], df['MeanTravelTimeSeconds'][-test_size:]

# %%
model = arch_model(train, p=2, q=2)

# %%
model_fit = model.fit()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-a0e793f6305e> in <module>
# ----> 1 model_fit = model.fit()
#
# c:\users\i539797\appdata\local\programs\python\python38-32\lib\site-packages\arch\univariate\base.py in fit(self, update_freq, disp, starting_values, cov_type, show_warning, first_obs, last_obs, tol, options, backcast)
#     589         )
#     590
# --> 591         self._adjust_sample(first_obs, last_obs)
#     592
#     593         resids = self.resids(self.starting_values())
#
# c:\users\i539797\appdata\local\programs\python\python38-32\lib\site-packages\arch\univariate\mean.py in _adjust_sample(self, first_obs, last_obs)
#     569         _last_obs_index = cutoff_to_index(last_obs, index, self._y.shape[0])
#     570         if _last_obs_index <= _first_obs_index:
# --> 571             raise ValueError("first_obs and last_obs produce in an empty array.")
#     572         self._fit_indices = [_first_obs_index, _last_obs_index]
#     573         self._fit_y = self._y[_first_obs_index:_last_obs_index]
#
# ValueError: first_obs and last_obs produce in an empty array.
